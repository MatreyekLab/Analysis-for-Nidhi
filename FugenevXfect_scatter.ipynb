# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

kozak_data = pd.read_csv ('Combined_data_IDT_Kozak.csv')
mCherry_data = pd.read_csv ('Combined_data_mCherry.csv')
merge = [kozak_data, mCherry_data]
combine_df = pd.concat(merge).reset_index(drop=True)
combine_df = combine_df[["Recombined_construct", "Reagent", "pct_mCherry"]]

sns.set_theme(style="whitegrid")
ax = sns.stripplot(x="Reagent", y="pct_mCherry", hue="Recombined_construct",
                   data=combine_df, palette="Set2", dodge=True)
plt.savefig('ReagentVmCherryExpression_Scatter.png')

# %%
sns
# Out:
# <module 'seaborn' from 'c:\\users\\tiena\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\seaborn\\__init__.py'>
